# %%
import pandas as pd

# %%
# %pwd
# Out:
# '/content'

# %%
atto_4way = pd.read_csv('/content/atto_4way.csv')
atto_6way = pd.read_csv('/content/atto_6way.csv')
atto_9way = pd.read_csv('/content/atto_9way.csv')
atto_none = pd.read_csv('/content/atto_none.csv')

# %%
atto_4way
# Out:
#    epoch_index     train_serial  train_loss  train_elapsed_time  \
# 0            0  20230919_223242    1.025026          241.024242
# 1            1  20230919_223242    0.359540          239.842582
# 2            2  20230919_223242    0.184269          240.193886
# 3            3  20230919_223242    0.125839          239.627470
# 4            4  20230919_223242    0.100577          240.062760
# 5            5  20230919_223242    0.083611          239.189787
# 6            6  20230919_223242    0.073530          239.407856
# 7            7  20230919_223242    0.063595          240.361176
# 8            8  20230919_223242    0.058967          239.989555
# 9            9  20230919_223242    0.052596          240.554324
#
#    train_accuracy  train_f1macro  val_loss  val_elapsed_time  val_accuracy  \
# 0        0.563725       0.108182  0.749897          4.507958        0.6965
# 1        0.868525       0.624736  0.675486          4.204007        0.7945
# ...

# %%
atto_4_val_loss = atto_4way['val_loss'].to_list()
atto_4_val_accuracy = atto_4way['val_accuracy'].to_list()

atto_6_val_loss = atto_6way['val_loss'].to_list()
atto_6_val_accuracy = atto_6way['val_accuracy'].to_list()

atto_none_val_loss = atto_none['val_loss'].to_list()
atto_none_val_accuracy = atto_none['val_accuracy'].to_list()

# %%
import matplotlib.pyplot as plt

# %%
plt.title('atto 4way augmentation vs 6 way')
plt.ylabel('val loss, val accuracy')
plt.xlabel('train epoch')
plt.plot(atto_4_val_loss, 'r--', label='4way_val_loss')
plt.plot(atto_4_val_accuracy, 'r', label='4way_val_accuracy')
plt.plot(atto_6_val_loss, 'b--', label='6way_val_loss')
plt.plot(atto_6_val_accuracy, 'b', label='6way_val_accuracy')

#plt.plot(atto_none_val_loss, 'g--', label='none_val_loss')
#plt.plot(atto_none_val_accuracy, 'g', label='none_val_accuracy')



plt.legend(loc=(0.65, 0.65), ncols=1, fontsize=8, shadow=True)
#plt.show()
plt.savefig('atto_4_way_vs_6_way.png', dpi=1000)

# %%
plt.subplot(2, 1, 1)

plt.title('atto none augmentation applied')

plt.ylabel('val loss')
plt.ylim(0.9, 1.5)

plt.plot(atto_none_val_loss, 'g--', label='val_loss')

plt.subplot(2,1,2)

plt.ylabel('val accuracy')
plt.xlabel('train epoch')

plt.ylim(0.3, 0.8)

plt.plot(atto_none_val_accuracy, 'g', label='val_accuracy')

#plt.show()

plt.savefig('atto_none_version1.png', dpi=1000)

# %%
plt.title('atto none augmentation')
plt.ylabel('val loss, val accuracy')
plt.xlabel('train epoch')

plt.plot(atto_none_val_loss, 'g--', label='val_loss')
plt.plot(atto_none_val_accuracy, 'g', label='val_accuracy')


plt.legend(loc='upper left', ncols=1, fontsize=8, shadow=True)
#plt.show()

plt.savefig('atto_none_version2.png', dpi=1000)

# %%
lr1e_4 = pd.read_csv('/content/lr1.0e-4.csv')
lr2e_4 = pd.read_csv('/content/lr2.0e-4.csv')
lr7e_5 = pd.read_csv('/content/lr7.0e-5.csv')
lr9e_5 = pd.read_csv('/content/lr9.0e-5.csv')

# %%
lr1e_4_val_loss = lr1e_4['val_loss'].to_list()
lr1e_4_val_accuracy = lr1e_4['val_accuracy'].to_list()

lr2e_4_val_loss = lr2e_4['val_loss'].to_list()
lr2e_4_val_accuracy = lr2e_4['val_accuracy'].to_list()

lr7e_5_val_loss = lr7e_5['val_loss'].to_list()
lr7e_5_val_accuracy = lr7e_5['val_accuracy'].to_list()

lr9e_5_val_loss = lr9e_5['val_loss'].to_list()
lr9e_5_val_accuracy = lr9e_5['val_accuracy'].to_list()

# %%
plt.subplot(2, 1, 1)
plt.title('convnext_v2 different lr performance')
plt.ylabel('val loss')

plt.xlim(0,9.0)

plt.plot(lr1e_4_val_loss, '--', label='1e_4_val_loss')
plt.plot(lr2e_4_val_loss, '--', label='2e_4_val_loss')
plt.plot(lr7e_5_val_loss, '--', label='7e_5_val_loss')
plt.plot(lr9e_5_val_loss, '--', label='9e_5_val_loss')

plt.legend(loc=(0.5, 0.8), ncols=2, fontsize=8)


plt.subplot(2, 1, 2)

plt.ylabel('val accuracy')
plt.xlim(0, 9.0)

plt.plot(lr1e_4_val_accuracy, ':', label='1e_4_val_accuracy')
plt.plot(lr2e_4_val_accuracy, ':', label='2e_4_val_accuracy')
plt.plot(lr7e_5_val_accuracy, ':', label='7e_5_val_accuracy')
plt.plot(lr9e_5_val_accuracy, ':', label='9e_5_val_accuracy')

plt.legend(loc='lower right', ncols=2, fontsize=8)
plt.xlabel('train epoch')


plt.savefig('lr_9.0_vs_7.0_vs_1.0_vs_2.0_version2.png')
plt.show()

# %%
plt.title('convnext_v2 different lr performance')
plt.ylabel('val loss')

plt.xlim(0, 9.3)

plt.plot(lr1e_4_val_loss, '--', label='1e_4_val_loss')
plt.plot(lr2e_4_val_loss, '--', label='2e_4_val_loss')
plt.plot(lr7e_5_val_loss, '--', label='7e_5_val_loss')
plt.plot(lr9e_5_val_loss, '--', label='9e_5_val_loss')

plt.legend(loc='upper right', ncols=2, fontsize=8, shadow=True)


plt.savefig('lr_9.0_vs_7.0_vs_1.0_vs_2.0_loss.png', dpi=1000)
plt.show()

plt.title('convnext_v2 different lr performance')
plt.ylabel('val accuracy')
plt.xlim(0, 9.3)

plt.plot(lr1e_4_val_accuracy, ':', label='1e_4_val_accuracy')
plt.plot(lr2e_4_val_accuracy, ':', label='2e_4_val_accuracy')
plt.plot(lr7e_5_val_accuracy, ':', label='7e_5_val_accuracy')
plt.plot(lr9e_5_val_accuracy, ':', label='9e_5_val_accuracy')

plt.legend(loc='lower right', ncols=2, fontsize=8, shadow=True)
plt.xlabel('train epoch')

plt.savefig('lr_9.0_vs_7.0_vs_1.0_vs_2.0_accuracy.png', dpi=1000)
plt.show()

# %%
base = pd.read_csv('/content/large.csv')
large = pd.read_csv('/content/base.csv')
nano = pd.read_csv('/content/nano.csv')

# %%
nano_val_loss = nano['val_loss'].to_list()
nano_val_accuracy = nano['val_accuracy'].to_list()

large_val_loss = large['val_loss'].to_list()
large_val_accuracy = large['val_accuracy'].to_list()

base_val_loss = base['val_loss'].to_list()
base_val_accuracy = base['val_accuracy'].to_list()

# %%
plt.title('convnext_v2 different model size')
plt.ylabel('val loss')

plt.plot(nano_val_loss, 'r--', label='nano_val_loss')
plt.plot(base_val_loss, 'g--', label='base_val_loss')
plt.plot(large_val_loss, 'b--', label='large_val_loss')


plt.legend(loc='upper right', ncols=2, fontsize=8, shadow=True)


plt.savefig('nano_vs_base_vs_large_loss.png', dpi=1000)
plt.show()

plt.title('convnext_v2 different model size')
plt.ylabel('val accuracy')

plt.plot(nano_val_accuracy, 'r:', label='nano_val_accuracy')
plt.plot(base_val_accuracy, 'g:', label='base_val_accuracy')
plt.plot(large_val_accuracy, 'b:', label='large_val_accuracy')


plt.legend(loc='lower right', ncols=2, fontsize=8, shadow=True)
plt.xlabel('train epoch')

plt.savefig('nano_vs_base_vs_large_accuracy.png', dpi=1000)
plt.show()

# %%
plt.subplot(2, 1, 1)
plt.title('convnext_v2 different lr performance')
plt.ylabel('val loss')

plt.xlim(0,9.0)

plt.plot(nano_val_loss, 'r--', label='nano_val_loss')
plt.plot(base_val_loss, 'g--', label='base_val_loss')
plt.plot(large_val_loss, 'b--', label='large_val_loss')

plt.legend(loc=(0.5, 0.8), ncols=2, fontsize=8)


plt.subplot(2, 1, 2)

plt.ylabel('val accuracy')
plt.xlim(0, 9.0)

plt.plot(nano_val_accuracy, 'r:', label='nano_val_accuracy')
plt.plot(base_val_accuracy, 'g:', label='base_val_accuracy')
plt.plot(large_val_accuracy, 'b:', label='large_val_accuracy')


plt.legend(loc='lower right', ncols=2, fontsize=8)
plt.xlabel('train epoch')


plt.savefig('nano_vs_base_large_version2.png')
plt.show()

# %%
base_4 = pd.read_csv('/content/4_nano.csv')
nano_4 = pd.read_csv('/content/4_base.csv')
atto_4 = pd.read_csv('/content/4_atto_10.csv')

# %%
nano4_val_loss = nano_4['val_loss'].to_list()
nano4_val_accuracy = nano_4['val_accuracy'].to_list()
nano4_val_f1 = nano_4['val_f1macro'].to_list()

atto4_val_loss = atto_4['val_loss'].to_list()
atto4_val_accuracy = atto_4['val_accuracy'].to_list()
atto4_val_f1 = atto_4['val_f1macro'].to_list()

base4_val_loss = base_4['val_loss'].to_list()
base4_val_accuracy = base_4['val_accuracy'].to_list()
nano4_val_f1 = base_4['val_f1macro'].to_list()

# %%
plt.title('4way augmented - different model size')
plt.ylabel('val loss')

plt.plot(nano4_val_loss, 'r--', label='nano4_val_loss')
plt.plot(base4_val_loss, 'g--', label='base4_val_loss')
plt.plot(atto4_val_loss, 'b--', label='atto4_val_loss')


plt.legend(loc='upper right', ncols=2, fontsize=8, shadow=True)


plt.savefig('4_way_nano_vs_base_loss.png', dpi=1000)
plt.show()

plt.title('4way augmented - different model size')
plt.ylabel('val accuracy')

plt.plot(nano4_val_accuracy, 'r:', label='nano4_val_accuracy')
plt.plot(base4_val_accuracy, 'g:', label='base4_val_accuracy')
plt.plot(atto4_val_accuracy, 'b:', label='atto4_val_accuracy')


plt.legend(loc='lower right', ncols=2, fontsize=8, shadow=True)
plt.xlabel('train epoch')

plt.savefig('4_way_nano_vs_base_accuracy.png', dpi=1000)
plt.show()

# %%
plt.subplot(2, 1, 1)
plt.title('4way augmented - different model size')
plt.ylabel('val loss')


plt.plot(nano4_val_loss, 'r--', label='nano4_val_loss')
plt.plot(base4_val_loss, 'g--', label='base4_val_loss')
plt.plot(atto4_val_loss, 'b--', label='atto4_val_loss')
plt.legend(loc=(0.5, 0.8), ncols=2, fontsize=8)


plt.subplot(2, 1, 2)
plt.ylabel('val f1macro')

plt.plot(nano4_val_accuracy, 'r-', label='nano4_f1_macro')
plt.plot(base4_val_accuracy, 'g-', label='base4_f1_macro')
plt.plot(atto4_val_accuracy, 'b-', label='atto4_f1_macro')
plt.legend(loc='lower right', ncols=2, fontsize=8)

plt.xlabel('train epoch')


plt.savefig('4way_nano_vs_base_version2.png')
plt.show()

# %%
nano_6 = pd.read_csv('/content/6_nano.csv')
atto_6 = pd.read_csv('/content/6_atto.csv')

# %%
nano6_val_loss = nano_6['val_loss'].to_list()
nano6_val_accuracy = nano_6['val_accuracy'].to_list()
nano6_val_f1 = nano_6['val_f1macro'].to_list()

atto6_val_loss = atto_6['val_loss'].to_list()
atto6_val_accuracy = atto_6['val_accuracy'].to_list()
atto6_val_f1 = atto_6['val_f1macro'].to_list()

# %%
plt.subplot(2, 1, 1)
plt.title('6way augmented - atto')
plt.ylabel('val loss')
plt.plot(atto6_val_loss, 'r--', label='atto6_val_loss')
plt.legend(loc='upper right', ncols=2, fontsize=8, shadow=True)

plt.subplot(2, 1, 2)
plt.ylabel('val accuracy')
plt.plot(atto6_val_accuracy, 'b:', label='atto6_val_accuracy')
plt.legend(loc='lower right', ncols=2, fontsize=8, shadow=True)
plt.xlabel('train epoch')

plt.savefig('6_way_atto.png', dpi=1000)
plt.show()

# %%
plt.subplot(2, 1, 1)
plt.title('6way augmented - nano')
plt.ylabel('val loss')
plt.plot(nano6_val_loss, 'r--', label='nano6_val_loss')
plt.legend(loc='upper right', ncols=2, fontsize=8, shadow=True)

plt.subplot(2, 1, 2)
plt.ylabel('val accuracy')
plt.plot(nano6_val_accuracy, 'b:', label='nano6_val_accuracy')
plt.legend(loc='lower right', ncols=2, fontsize=8, shadow=True)

plt.legend(loc='lower right', ncols=2, fontsize=8, shadow=True)
plt.xlabel('train epoch')
plt.savefig('6_way_nano.png', dpi=1000)
plt.show()

# %%
nano_4 = pd.read_csv('/content/4_base.csv')
atto_4 = pd.read_csv('/content/4_atto.csv')

nano_6 = pd.read_csv('/content/6_nano.csv')
atto_6 = pd.read_csv('/content/6_atto.csv')

# %%
nano6_val_loss = nano_6['val_loss'].to_list()
nano6_val_accuracy = nano_6['val_accuracy'].to_list()
nano6_val_f1 = nano_6['val_f1macro'].to_list()

atto6_val_loss = atto_6['val_loss'].to_list()
atto6_val_accuracy = atto_6['val_accuracy'].to_list()
atto6_val_f1 = atto_6['val_f1macro'].to_list()

nano4_val_loss = nano_4['val_loss'].to_list()
nano4_val_accuracy = nano_4['val_accuracy'].to_list()
nano4_val_f1 = nano_4['val_f1macro'].to_list()

atto4_val_loss = atto_4['val_loss'].to_list()
atto4_val_accuracy = atto_4['val_accuracy'].to_list()
atto4_val_f1 = atto_4['val_f1macro'].to_list()

# %%
plt.subplot(2, 1, 1)
plt.title('4way_vs_6way - nano')
plt.ylabel('val loss')
plt.plot(nano6_val_loss, 'r--', label='nano6_val_loss')
plt.plot(nano4_val_loss, 'b--', label='nano4_val_loss')
plt.legend(loc='upper right', ncols=2, fontsize=8, shadow=True)

plt.subplot(2, 1, 2)
plt.ylabel('val accuracy')
plt.plot(nano6_val_accuracy, 'r:', label='nano6_val_accuracy')
plt.plot(nano4_val_accuracy, 'b:', label='nano4_val_accuracy')
plt.legend(loc='lower right', ncols=2, fontsize=8, shadow=True)
plt.xlabel('train epoch')

plt.savefig('4_vs_6_way_nano.png', dpi=1000)
plt.show()

# %%
plt.subplot(2, 1, 1)
plt.title('4_vs_6way - atto')
plt.ylabel('val loss')
plt.plot(atto6_val_loss, 'r--', label='atto6_val_loss')
plt.plot(atto4_val_loss, 'b--', label='atto4_val_loss')
plt.legend(loc='upper right', ncols=2, fontsize=8, shadow=True)

plt.subplot(2, 1, 2)
plt.ylabel('val accuracy')
plt.plot(atto6_val_accuracy, 'r:', label='atto6_val_accuracy')
plt.plot(atto4_val_accuracy, 'b:', label='atto4_val_accuracy')
plt.legend(loc='lower right', ncols=2, fontsize=8, shadow=True)

plt.xlabel('train epoch')
plt.savefig('4_vs_6_way_atto.png', dpi=1000)
plt.show()
